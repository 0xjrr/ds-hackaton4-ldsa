# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import os
import re
import hashlib
import numpy as np

from tqdm import tqdm

from spacy.matcher import Matcher
from sklearn.metrics import accuracy_score, f1_score 
from nltk.tokenize import WordPunctTokenizer
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.model_selection import train_test_split
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
df_dataset = pd.read_csv("data/dataset.csv")

# %%
df_dataset
# Out:
#                                                    text        date  \
# 0     Hello, Does it matter iff I use Visa or Master...    7-6-2022
# 1     Good afternoon, I just got refunded for my pur...  16-11-2022
# 2           Hello, I got billed ann extra pound! Thanks   4-12-2022
# 3     Hi, How long does it take for a transfer to sh...  23-11-2022
# 4     hi, When can I use money sent to my accountt? ...   17-4-2022
# ...                                                 ...         ...
# 9370  good afternoon, I think someone may be using m...   22-6-2022
# 9371  good morning, Help, I need to top up my accoun...    7-4-2022
# 9372  hi, I made an international purchasee, but the...   7-12-2022
# 9373     hi, Why is my card not working anymore? Thanks   1-11-2022
# 9374  Hello, How many different cards can I havee fo...   24-4-2022
#
#                               category language
# 0                   visa_or_mastercard       en
# 1               reverted_card_payment?       en
# 2            extra_charge_on_statement       en
# 3                      transfer_timing       en
# 4                      transfer_timing       en
# ...                                ...      ...
# 9370                  compromised_card       en
# 9371          top_up_by_cash_or_cheque       en
# 9372  card_payment_wrong_exchange_rate       en
# 9373                  card_not_working       en
# 9374                getting_spare_card       en
#
# [9375 rows x 4 columns]

# %%
df_mapping = pd.read_csv("data/mapping.csv")

# %%
df_mapping
# Out:
#                             category   class
# 0                       card_arrival    card
# 1                       card_linking    card
# 2                      exchange_rate  others
# 3   card_payment_wrong_exchange_rate    card
# 4          extra_charge_on_statement  others
# ..                               ...     ...
# 72            cash_withdrawal_charge    cash
# 73              card_about_to_expire    card
# 74           apple_pay_or_google_pay  others
# 75                verify_my_identity  others
# 76                   country_support  others
#
# [77 rows x 2 columns]

# %%
df_merged = pd.merge(left=df_dataset, right=df_mapping, on='category', how='left', suffixes=(None, 'map'))

# %%
df_merged
# Out:
#                                                    text        date  \
# 0     Hello, Does it matter iff I use Visa or Master...    7-6-2022
# 1     Good afternoon, I just got refunded for my pur...  16-11-2022
# 2           Hello, I got billed ann extra pound! Thanks   4-12-2022
# 3     Hi, How long does it take for a transfer to sh...  23-11-2022
# 4     hi, When can I use money sent to my accountt? ...   17-4-2022
# ...                                                 ...         ...
# 9370  good afternoon, I think someone may be using m...   22-6-2022
# 9371  good morning, Help, I need to top up my accoun...    7-4-2022
# 9372  hi, I made an international purchasee, but the...   7-12-2022
# 9373     hi, Why is my card not working anymore? Thanks   1-11-2022
# 9374  Hello, How many different cards can I havee fo...   24-4-2022
#
#                               category language     class
# 0                   visa_or_mastercard       en      card
# 1               reverted_card_payment?       en      card
# 2            extra_charge_on_statement       en    others
# 3                      transfer_timing       en  transfer
# 4                      transfer_timing       en  transfer
# ...                                ...      ...       ...
# 9370                  compromised_card       en      card
# 9371          top_up_by_cash_or_cheque       en      cash
# 9372  card_payment_wrong_exchange_rate       en      card
# 9373                  card_not_working       en      card
# 9374                getting_spare_card       en      card
#
# [9375 rows x 5 columns]

# %% [raw]
# df_merged.to_csv("data\dataset_mapped.csv")

# %%
df_merged["class"].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df_merged["language"].value_counts().plot.barh()
# Out:
# <AxesSubplot:>

# %%
df_merged.loc[df_merged["language"] == "pt"]
# Out:
#                                                    text        date  \
# 28    Olá, Posso obter uma atualização sobre o meu c...   11-7-2022
# 29    Boas, Encontrei o meu cartão no meu casaco est...  26-12-2022
# 38    Olá, Quero reativar o meu cartão. Pensei que o...    7-4-2022
# 39    Olá, E se eu quiser adicionar um cartão que já...    2-8-2022
# 49    Olá, Posso voltar a colocar o meu cartão antig...   22-7-2022
# ...                                                 ...         ...
# 9273  Olá, Encontrei o cartão que pensei ter perdido...   29-8-2022
# 9279  Boas, Quero reativar o meu cartão. Pensei que ...   12-1-2022
# 9290  Boa noite, Como faço para vincular um novo car...  20-11-2022
# 9306  Boa noite, Por que não recebi o meu novo cartã...    5-8-2022
# 9343  Boa tarde, O meu cartão ainda não chegou pelo ...    3-5-2022
#
#                                  category language     class
# 28              extra_charge_on_statement       pt    others
# 29         cash_withdrawal_not_recognised       pt      cash
# 38              unable_to_verify_identity       pt    others
# 39    direct_debit_payment_not_recognised       pt    others
# 49                             change_pin       pt  security
# ...                                   ...      ...       ...
# 9273                      receiving_money       pt    others
# 9279          get_disposable_virtual_card       pt      card
# 9290                         card_arrival       pt      card
# 9306                          atm_support       pt    others
# 9343                   verify_my_identity       pt    others
#
# [300 rows x 5 columns]

# %%
df_clean = df_merged.loc[df_merged["language"] == "en"].copy()

# %%
df_clean = df_clean.drop(columns=["date", "category", "language"])

# %%
df_clean
# Out:
#                                                    text     class
# 0     Hello, Does it matter iff I use Visa or Master...      card
# 1     Good afternoon, I just got refunded for my pur...      card
# 2           Hello, I got billed ann extra pound! Thanks    others
# 3     Hi, How long does it take for a transfer to sh...  transfer
# 4     hi, When can I use money sent to my accountt? ...  transfer
# ...                                                 ...       ...
# 9370  good afternoon, I think someone may be using m...      card
# 9371  good morning, Help, I need to top up my accoun...      cash
# 9372  hi, I made an international purchasee, but the...      card
# 9373     hi, Why is my card not working anymore? Thanks      card
# 9374  Hello, How many different cards can I havee fo...      card
#
# [9073 rows x 2 columns]

# %%
df_clean.isna().sum()
# Out:
# text      0
# class    35
# dtype: int64

# %%
df_clean[df_clean["class"].isna()]
# Out:
#                                                    text class
# 24          We have hope. Rebellions are built on hope.   NaN
# 1155  I'm one with the Force, and the Force will gui...   NaN
# 1305  Lesson one from this experience: Realize how m...   NaN
# 1459  The belonging you seek is not behind you; it i...   NaN
# 2023     I am one with the Force. The Force is with me.   NaN
# 2107            Try not. Do or do not. There is no try.   NaN
# 2176                    That's not how the Force works!   NaN
# 2222                         No one’s ever really gone.   NaN
# 2412                            Never tell me the odds!   NaN
# 2453                  I'll never turn to the dark side.   NaN
# 2829                     Don't underestimate the Force.   NaN
# 3381  We fight for justice because justice is the fu...   NaN
# 3392  No longer certain that one ever does win a war...   NaN
# 3415  Once you start down the dark path, forever wil...   NaN
# 3419  For my ally is the Force, and a powerful ally ...   NaN
# 3869          Let the past die. Kill it if you have to.   NaN
# 4418       Your eyes can deceive you; don’t trust them.   NaN
# 4715  Train yourself to let go of everything you fea...   NaN
# 5382     I know how to run without you holding my hand!   NaN
# 5542  We’ll always be with you. No one’s ever really...   NaN
# 5646  The ability to speak does not make you intelli...   NaN
# 5764                Your focus determines your reality.   NaN
# 5852  Now I know there is something strong than fear...   NaN
# 5977  Who’s the more foolish: the fool or the fool w...   NaN
# 6099                         May the Force be with you.   NaN
# 6756            Sometimes to heal, you must first hurt.   NaN
# 6818            Reality doesn’t care if you believe it.   NaN
# 7109  In a dark place we find ourselves and a little...   NaN
# 7329  Authority can be given, but leadership must be...   NaN
# 7431  Rule 23: Never pull sentry duty on an empty st...   NaN
# 7575     Luminous beings we are, not this crude matter.   NaN
# 8353            You must unlearn what you have learned.   NaN
# 8689  Sometimes we must let go of our pride and do w...   NaN
# 8877                Your focus determines your reality.   NaN
# 8928  Close your eyes. Feel it. The light...it's alw...   NaN

# %%
df_clean = df_clean.loc[df_clean["class"].notna()]

# %%
df_clean.isna().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %%
df_aux = df_clean.copy()

# %%
def remove_punctuation(text):


    text = re.sub(r'[^\w\s]+', '', text)

    return text.lower()

# %%
def preprocess_text(df):

    df_processed = df.copy()
    df_processed["text"] = df_processed["text"].apply(lambda x: remove_punctuation(x))
    return df_processed
df_aux = preprocess_text(df_aux)

# %%
df_aux["text"]
# Out:
# 0       hello does it matter iff i use visa or masterc...
# 1       good afternoon i just got refunded for my purc...
# 2               hello i got billed ann extra pound thanks
# 3       hi how long does it take for a transfer to sho...
# 4       hi when can i use money sent to my accountt be...
#                               ...
# 9370    good afternoon i think someone may be using my...
# 9371    good morning help i need to top up my account ...
# 9372    hi i made an international purchasee but the e...
# 9373         hi why is my card not working anymore thanks
# 9374    hello how many different cards can i havee for...
# Name: text, Length: 9038, dtype: object

# %%
class Selector(BaseEstimator, TransformerMixin):
    """
    Transformer to select a column from the dataframe to perform additional transformations on
    """ 
    def __init__(self, key):
        self.key = key
        
    def fit(self, X, y=None):
        return self
    

class TextSelector(Selector):
    """
    Transformer to select a single column from the data frame to perform additional transformations on
    Use on text columns in the data
    """
    def transform(self, X):
        return X[self.key]
    
    
class NumberSelector(Selector):
    """
    Transformer to select a single column from the data frame to perform additional transformations on
    Use on numeric columns in the data
    """
    def transform(self, X):
        return X[[self.key]]

# %%
df_clean_aux = df_aux.copy()

df_clean_aux["nb_words"] = df_clean_aux['text'].str.split().map(len)
df_clean_aux["doc_length"] = df_clean_aux['text'].map(len)
df_clean_aux["avg_word_length"] =  df_clean_aux['text'].apply(lambda x: np.mean([len(t) for t in x.split(' ')]) if len([len(t) for t in x.split(' ')]) > 0 else 0)

df_clean_aux
# Out:
#                                                    text     class  nb_words  \
# 0     hello does it matter iff i use visa or masterc...      card        11
# 1     good afternoon i just got refunded for my purc...      card        15
# 2             hello i got billed ann extra pound thanks    others         8
# 3     hi how long does it take for a transfer to sho...  transfer        16
# 4     hi when can i use money sent to my accountt be...  transfer        12
# ...                                                 ...       ...       ...
# 9370  good afternoon i think someone may be using my...      card        12
# 9371  good morning help i need to top up my account ...      cash        18
# 9372  hi i made an international purchasee but the e...      card        13
# 9373       hi why is my card not working anymore thanks      card         9
# 9374  hello how many different cards can i havee for...      card        13
#
#       doc_length  avg_word_length
# 0             56         4.181818
# 1             82         4.533333
# 2             41         4.250000
# 3             71         3.500000
# 4             56         3.750000
# ...          ...              ...
# 9370          64         4.416667
# 9371          82         3.611111
# 9372          75         4.846154
# 9373          44         4.000000
# 9374          70         4.461538
#
# [9038 rows x 5 columns]

# %%
text_pipe = Pipeline([
                ('selector', TextSelector("text")),
                ('tfidf', TfidfVectorizer())
            ])
nb_words_pipe =  Pipeline([
                ('selector', NumberSelector(key='nb_words')),
                ('standard', StandardScaler())
            ])
doc_length_pipe =  Pipeline([
                ('selector', NumberSelector(key='doc_length')),
                ('standard', StandardScaler())
            ])
avg_word_length_pipe =  Pipeline([
                ('selector', NumberSelector(key='avg_word_length')),
                ('standard', StandardScaler()),
            ])


feats = FeatureUnion([('text', text_pipe), 
                      ('nb_words', nb_words_pipe),
                      ('doc_length', doc_length_pipe),
                      ('avg_word_length', avg_word_length_pipe)])

# %%
def improved_pipeline(feats, X_train, X_test, y_train, y_test):
    """
    Train a Random Forest using sklearn's Pipeline and return the trained model and its accuracy in the test set.
    Don't forget to add the feats to the Pipeline!
    """
    
    # pipe = (...)
    # pipe.fit(...)
    # (...)
    
    # YOUR CODE HERE
    
    pipe = Pipeline([
        ('feats',feats),
        ('classifier', RandomForestClassifier()),])
    
    pipe.fit(X_train, y_train)

    preds = pipe.predict(X_test)
    acc = accuracy_score(y_true=y_test, y_pred=preds)
    
    #raise NotImplementedError()
    
    return pipe, acc

# %%
Y = df_clean_aux["class"]
X = df_clean_aux.drop(columns="class")

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42, stratify=Y)
pipeline_model, pipeline_acc = improved_pipeline(feats, X_train, X_test, y_train, y_test)

# %%
pipe = Pipeline([
        ('feats',feats),
        ('classifier', RandomForestClassifier()),])
    
pipe.fit(X_train, y_train)

preds = pipe.predict(X_test)
acc = accuracy_score(y_true=y_test, y_pred=preds)
f1 = f1_score(y_true=y_test, y_pred=preds, average='micro')

# %%
X_test["class"] = preds
# Out:
# /var/folders/sj/c0wtvkk15b92vcqw5rhy939r0000gn/T/ipykernel_3469/3848072420.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X_test["class"] = preds

# %%
X_test
# Out:
#                                                    text  nb_words  doc_length  \
# 7417  good morning ii used my card to top up but its...        21         100
# 1040  good morning i would likee to top up my accoun...        19          97
# 6668  good morning my foreign currencyy exchange has...        11          78
# 8315  hello whats the card you sent mes tracking num...        11          63
# 5005       hi how do i get myy card active best regards        10          44
# ...                                                 ...       ...         ...
# 7684  good evening what is the basis of your exchang...        12          66
# 681   good evening i sent a payment but it isnt show...        15          70
# 5076  hi how doo you find the exchange rate best reg...        10          50
# 1977  good morning where doo i find out about exchan...        12          66
# 5284  good afternoon myy bag got stolen with all my ...        23         113
#
#       avg_word_length     class
# 7417         3.809524      card
# 1040         4.157895  transfer
# 6668         6.181818    others
# 8315         4.818182      card
# 5005         3.500000      card
# ...               ...       ...
# 7684         4.583333    others
# 681          3.733333      card
# 5076         4.100000    others
# 1977         4.583333    others
# 5284         3.956522      card
#
# [1808 rows x 5 columns]
